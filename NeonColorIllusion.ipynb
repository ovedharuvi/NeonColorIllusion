# %%
from LF3 import *
from LFutils import *
import numpy as np
import cv2
import matplotlib.pylab as plt
from skimage import transform,io

# %%
img = io.imread('neon_13.png')
img= img[:,:,:-1]
print ('Image shape:{}, Image data type:{}'.format(img.shape,img.dtype))

plt.imshow(img, cmap = 'gray')
plt.xticks([]), plt.yticks([])  # to hide tick values on X & Y axis
plt.show()
# Out:
# Image shape:(315, 430, 3), Image data type:uint8

# %%
filled_img = line_filling(img)
plt.imshow(filled_img, cmap = 'gray')
plt.xticks([]), plt.yticks([])  # to hide tick values on X & Y axis
plt.show()

plt.imshow(img-filled_img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-8a751c1dcb8e> in <module>
# ----> 1 filled_img = line_filling(img)
#       2 plt.imshow(filled_img, cmap = 'gray')
#       3 plt.xticks([]), plt.yticks([])  # to hide tick values on X & Y axis
#       4 plt.show()
#       5
#
# ~\PycharmProjects\pythonProject\LF3.py in line_filling(input_image)
#      22     LDR = 1
#      23     img = preprocess(input_image)
# ---> 24     scale_levels = 4
#      25     im_scel = np.zeros((img.shape[0], img.shape[1], scale_levels))
#      26     im_scel_tot = np.zeros(img.shape)
#
# TypeError: 'tuple' object cannot be interpreted as an integer
